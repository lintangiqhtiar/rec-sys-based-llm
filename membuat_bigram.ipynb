# %% [markdown]
# <a href="https://colab.research.google.com/github/lintangiqhtiar/rec-sys-based-llm/blob/main/membuat_bigram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
df = pd.read_csv("reviews.csv")

# %%
df = df[df['label']=='Negative']

# %%
df
# Out:
#                                                   Review     label  confidence
# 1      harusnya proses itu setelah data dikirim baru ...  Negative    0.988940
# 3      ini aplikasinya kenapa sihkok mau buat sim bar...  Negative    0.994384
# 4      aplikasi payah duit sudah dibayar tapi muncul ...  Negative    0.999813
# 9                                       verifikasi gagal  Negative    0.999831
# 10                                                sampah  Negative    0.999882
# ...                                                  ...       ...         ...
# 33252  pada saat daftar tes psikotes gagal terus nik ...  Negative    0.866586
# 33255  banyak yang masih pengembangan tidak tersedia ...  Negative    0.860257
# 33256  aplikasinya butut orang mau login saja di pers...  Negative    0.999857
# 33257  verifikasi nomor telepon untuk masuk kok susah...  Negative    0.999558
# 33260  kenapa katanya layanan belum tersedia ada masa...  Negative    0.987648
#
# [11856 rows x 3 columns]

# %%
#save df
df.to_csv("negative_reviews.csv", index=False)

# %% [markdown]
# PREPOCESSING

# %%
df = pd.read_csv("negative_reviews.csv")

# %%
with open ('indonesian_stopword_1.txt', 'r') as file:
    indonesian_stop_words = [line.strip() for line in file.readlines()]

# %%
df['Review'] = df['Review'].dropna()

# %%
def remove_stopwords(text, stopwords):
    words = text.split()
    words = [word for word in words if word.lower() not in stopwords]
    return ' '.join(words)
df['clean_text'] = df['Review'].apply(lambda x: remove_stopwords(x, indonesian_stop_words))
df.head()
# Out:
#                                               Review     label  confidence  \
# 0  harusnya proses itu setelah data dikirim baru ...  Negative    0.988940
# 1  ini aplikasinya kenapa sihkok mau buat sim bar...  Negative    0.994384
# 2  aplikasi payah duit sudah dibayar tapi muncul ...  Negative    0.999813
# 3                                   verifikasi gagal  Negative    0.999831
# 4                                             sampah  Negative    0.999882
#
#                                           clean_text
# 0  proses data dikirim validasi data data pembaya...
# 1  aplikasinya sihkok sim tulisannya layanan ters...
# 2  aplikasi payah duit dibayar muncul notifikasi ...
# 3                                   verifikasi gagal
# 4                                             sampah

# %%
df.head(1)
# Out:
#                                               Review     label  confidence  \
# 0  harusnya proses itu setelah data dikirim baru ...  Negative     0.98894
#
#                                           clean_text
# 0  proses data dikirim validasi data data pembaya...

# %%
data = df.copy()

# %%
data
# Out:
#                                                   Review     label  \
# 0      harusnya proses itu setelah data dikirim baru ...  Negative
# 1      ini aplikasinya kenapa sihkok mau buat sim bar...  Negative
# 2      aplikasi payah duit sudah dibayar tapi muncul ...  Negative
# 3                                       verifikasi gagal  Negative
# 4                                                 sampah  Negative
# ...                                                  ...       ...
# 11851  pada saat daftar tes psikotes gagal terus nik ...  Negative
# 11852  banyak yang masih pengembangan tidak tersedia ...  Negative
# 11853  aplikasinya butut orang mau login saja di pers...  Negative
# 11854  verifikasi nomor telepon untuk masuk kok susah...  Negative
# 11855  kenapa katanya layanan belum tersedia ada masa...  Negative
#
#        confidence                                         clean_text
# 0        0.988940  proses data dikirim validasi data data pembaya...
# 1        0.994384  aplikasinya sihkok sim tulisannya layanan ters...
# 2        0.999813  aplikasi payah duit dibayar muncul notifikasi ...
# 3        0.999831                                   verifikasi gagal
# 4        0.999882                                             sampah
# ...           ...                                                ...
# 11851    0.866586           daftar tes psikotes gagal nik cek proses
# 11852    0.860257  pengembangan tersedia bintang 1 sim 1 bintang ...
# 11853    0.999857  aplikasinya butut orang login persulit otp uda...
# 11854    0.999558  verifikasi nomor telepon masuk susah banget ya...
# 11855    0.987648               layanan tersedia kah tolong jelaskan
#
# [11856 rows x 4 columns]

# %%
#menghapus kolom review label dan confidence
data = data.drop(columns=['Review', 'label', 'confidence'], axis=1)

# %%
import pandas as pd
import gensim
from gensim.models.phrases import Phrases, Phraser

# Contoh DataFrame
# data = {
#     'clean_text': [
#         "proses data dikirim validasi data data pembayaran namanya perampokan",
#         "anggap gagal 3 rugi puluh ribu pakai bank bank negara indonesia bank tekor 50 ribu"
#     ]
# }

# df = pd.DataFrame(data)

# Tokenisasi setiap teks menjadi list kata
sentences = [text.split() for text in data['clean_text']]

# Membuat bigram dan trigram model
bigram = Phrases(sentences, min_count=2, threshold=5)
trigram = Phrases(bigram[sentences], threshold=5)

bigram_model = Phraser(bigram)
trigram_model = Phraser(trigram)

# Transformasi teks ke dalam bentuk bigram dan trigram
data['clean_text_bigram'] = [' '.join(bigram_model[sent]) for sent in sentences]
data['clean_text_trigram'] = [' '.join(trigram_model[bigram_model[sent]]) for sent in sentences]

print(data[['clean_text', 'clean_text_bigram', 'clean_text_trigram']])
# Out:
#                                               clean_text  \
# 0      proses data dikirim validasi data data pembaya...
# 1      aplikasinya sihkok sim tulisannya layanan ters...
# 2      aplikasi payah duit dibayar muncul notifikasi ...
# 3                                       verifikasi gagal
# 4                                                 sampah
# ...                                                  ...
# 11851           daftar tes psikotes gagal nik cek proses
# 11852  pengembangan tersedia bintang 1 sim 1 bintang ...
# 11853  aplikasinya butut orang login persulit otp uda...
# 11854  verifikasi nomor telepon masuk susah banget ya...
# 11855               layanan tersedia kah tolong jelaskan
#
#                                        clean_text_bigram  \
# 0      proses data dikirim validasi_data data pembaya...
# 1      aplikasinya sihkok sim tulisannya_layanan ters...
# 2      aplikasi payah duit_dibayar muncul_notifikasi ...
# 3                                       verifikasi gagal
# 4                                                 sampah
# ...                                                  ...
# 11851           daftar tes_psikotes gagal nik cek proses
# 11852  pengembangan tersedia bintang_1 sim 1 bintang ...
# 11853  aplikasinya butut orang login persulit otp uda...
# 11854  verifikasi nomor_telepon masuk susah_banget ya...
# 11855               layanan_tersedia kah tolong jelaskan
#
#                                       clean_text_trigram
# 0      proses data dikirim validasi_data data pembaya...
# 1      aplikasinya sihkok sim tulisannya_layanan ters...
# 2      aplikasi payah duit_dibayar muncul_notifikasi ...
# 3                                       verifikasi_gagal
# 4                                                 sampah
# ...                                                  ...
# 11851           daftar tes_psikotes gagal nik cek proses
# 11852  pengembangan tersedia bintang_1 sim 1 bintang ...
# 11853  aplikasinya butut orang login persulit otp uda...
# 11854  verifikasi_nomor_telepon masuk susah_banget ya...
# 11855               layanan_tersedia kah tolong jelaskan
#
# [11856 rows x 3 columns]

# %%
data['clean_text_trigram']
# Out:
# 0        proses data dikirim validasi_data data pembaya...
# 1        aplikasinya sihkok sim tulisannya_layanan ters...
# 2        aplikasi payah duit_dibayar muncul_notifikasi ...
# 3                                         verifikasi_gagal
# 4                                                   sampah
#                                ...
# 11851             daftar tes_psikotes gagal nik cek proses
# 11852    pengembangan tersedia bintang_1 sim 1 bintang ...
# 11853    aplikasinya butut orang login persulit otp uda...
# 11854    verifikasi_nomor_telepon masuk susah_banget ya...
# 11855                 layanan_tersedia kah tolong jelaskan
# Name: clean_text_trigram, Length: 11856, dtype: object

# %%
#save bigranm
data.to_csv('clean_text_bigram_trigram.csv', index=False)
